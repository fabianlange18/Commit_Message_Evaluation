# %% [markdown]
# # K-Means Clustering Approach

# %% [markdown]
# #### Load Data and spaCy Model

# %%
import pandas as pd

# %% [markdown]
# Execute this block for all data:

# %%
data = pd.read_pickle("data/02_All_Decreased_Filesize.pkl")

# %% [markdown]
# Execute this block for the Frequent Committers Subset:

# %%
data = pd.read_pickle('data/03_Subset_Frequent_Committers.pkl')

# %%
data.head(3)
# Out:
#                                              message  \
# 0  Fixed an error happening when the memory stats...
# 1                         Updated setup.py [skip CI]
# 2            Fixed an exposure test [skip hazardlib]
#
#                committer_email             project
# 0  michele.simionato@gmail.com       gem_oq-engine
# 1  michele.simionato@gmail.com  micheles_decorator
# 2  michele.simionato@gmail.com       gem_oq-engine

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Take a Subset

# %%
subset_size = 100000

messages = data["message"][:subset_size].tolist()

# %% [markdown]
# #### Build Document Vectors

# %%
vectors = []

docs = nlp.pipe(messages)

for doc in docs:
    vectors.append(doc.vector)

# %% [markdown]
# ## Clustering the Subset with K-Means

# %% [markdown]
# #### Training

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(100)
kmeans.fit(vectors)
kmeans_prediction = kmeans.predict(vectors)

# %% [markdown]
# #### Evaluation

# %%
from utils.k_means import k_means_summary

k_means_summary = k_means_summary(kmeans_prediction, kmeans.n_clusters, data)
k_means_summary
# Out:
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Committers'][label] = int(len(commiter_emails_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Committer'][label] = float(np.mean(list(commiter_emails_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common committer'][label] = commiter_emails_count.most_common(1)[0]
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Number of different Projects'][label] = int(len(projects_count))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Average number of commits per different Project'][label] = float(np.mean(list(projects_count.values())))
# /Users/fabian/Developer/HPI/02 Trends AI:DL/utils/k_means.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k_means_summary['Most common project'][label] = projects_count.most_common(1)[0]
#     Number of Messages  Number of different Committers  \
# 0                395.0                            21.0
# 1               1290.0                            41.0
# 2               1268.0                            46.0
# 3                869.0                            42.0
# 4                597.0                            29.0
# ..                 ...                             ...
# 95               770.0                            41.0
# 96               458.0                            40.0
# 97               944.0                            40.0
# 98               915.0                            35.0
# 99               156.0                            34.0
#
#     Average number of commits per different Committer  \
# 0                                           18.809524
# 1                                           31.463415
# 2                                           27.565217
# 3                                           20.690476
# 4                                           20.586207
# ..                                                ...
# 95                                          18.780488
# 96                                          11.450000
# 97                                          23.600000
# 98                                          26.142857
# 99                                           4.588235
#
#                  Most common committer  Number of different Projects  \
# 0                 ('avwu@qq.com', 213)                          44.0
# 1          ('taylor@laravel.com', 603)                         112.0
# 2   ('aaron.patterson@gmail.com', 120)                         173.0
# 3           ('P.Rudiger@ed.ac.uk', 65)                         148.0
# 4   ('postmodern.mod3@gmail.com', 194)                         114.0
# ..                                 ...                           ...
# 95        ('jmettraux@gmail.com', 170)                         154.0
# 96      ('igor.kroitor@gmail.com', 88)                          89.0
# 97         ('thatch45@gmail.com', 183)                         144.0
# 98                ('avwu@qq.com', 181)                          81.0
# 99         ('crynobone@gmail.com', 38)                          69.0
#
#     Average number of commits per different Project  \
# 0                                          8.977273
# 1                                         11.517857
# 2                                          7.329480
# 3                                          5.871622
# 4                                          5.236842
# ..                                              ...
# 95                                         5.000000
# 96                                         5.146067
# 97                                         6.555556
# 98                                        11.296296
# 99                                         2.260870
#
#            Most common project
# 0        ('avwo_whistle', 209)
# 1   ('laravel_framework', 389)
# 2      ('saltstack_salt', 165)
# 3       ('saltstack_salt', 81)
# 4    ('ronin-ruby_ronin', 104)
# ..                         ...
# 95     ('floraison_flor', 137)
# 96           ('ccxt_ccxt', 88)
# 97     ('saltstack_salt', 301)
# 98       ('avwo_whistle', 179)
# 99           ('ccxt_ccxt', 14)
#
# [100 rows x 7 columns]

# %%
k_means_summary.describe()
# Out:
#        Number of Messages  Number of different Committers  \
# count          100.000000                      100.000000
# mean           781.450000                       33.350000
# std            450.961383                       13.955467
# min             83.000000                        2.000000
# 25%            437.750000                       25.000000
# 50%            771.500000                       39.500000
# 75%           1038.500000                       44.000000
# max           2508.000000                       49.000000
#
#        Average number of commits per different Committer  \
# count                                         100.000000
# mean                                           27.612337
# std                                            20.893710
# min                                             4.588235
# 25%                                            17.559470
# 50%                                            22.765625
# 75%                                            29.932292
# max                                           142.000000
#
#        Number of different Projects  \
# count                    100.000000
# mean                      98.340000
# std                       57.472562
# min                        2.000000
# 25%                       45.500000
# 50%                       99.000000
# 75%                      145.000000
# max                      229.000000
#
#        Average number of commits per different Project
# count                                       100.000000
# mean                                         12.362748
# std                                          17.862529
# min                                           2.260870
# 25%                                           5.306960
# 50%                                           6.833621
# 75%                                          11.351687
# max                                         142.000000

# %%
from utils.k_means import print_k_means_classes

print_k_means_classes(kmeans_prediction, kmeans.n_clusters, data[:subset_size])
# Out:
# ________________ Class 0 ________________
#
# ___
# 1)
# Rounding avg lon, lat
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# client/interfaces: Adds SendEvent function signature
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 3)
# shared/util: IsFalse description
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# lxd: Adds type field to instance API output
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# device: Links gpu device
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# lxd: Enable gorilla UseEncodedPath
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# client/lxd: log websocket URL
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# device/gpu: Updates unix function usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# client/interfaces: Adds network peer management function definitions
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd: migrateInstance usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 395
# Most common committers:
# [('avwu@qq.com', 213), ('duncan.macleod@ligo.org', 54)]
# Most common project:
# ('avwo_whistle', 209)
#
#
#
# ________________ Class 1 ________________
#
# ___
# 1)
# Increased weight of nonparametric sources by <I> [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed eid to be an uint<I>, not float<I>!
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Rename function and fixed unused variable (Closes #<I>).
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 4)
# Fixes a bug when using closure route with custom illuminate.route.dispatcher (e.g Illuminate\Routing\ControllerDispatcher).
#
# <URL>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_framework
# ___
# 5)
# Use App::terminate() instead of Route::after() to close open memory
# handler. Closes #<I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_memory
# ___
# 6)
# Fixed usage of $this in scope context (only supported by PHP<I>+),
#
# Closes orchestral/platform#<I>.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 7)
# fixes some bug and implements orchestral/widget@9a<I>a3
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 8)
# Change Orchestra\Auth\AuthManager::createDatabaseDriver() visibility based on laravel/framework@e<I>c changes
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 9)
# [<I>] Reintroduce ServiceProvider::when(), which allow registering/loading service provider only when events is fired.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   illuminate_support
# ___
# 10)
# Move toward future compatibility using unicode strings, but cast to native str as workaround for #<I>, #<I>, and #<I>.
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   pypa_setuptools
# _________________
#
# Number of messages in this class: 1290
# Most common committers:
# [('taylor@laravel.com', 603), ('koenkanters94@gmail.com', 80)]
# Most common project:
# ('laravel_framework', 389)
#
#
#
# ________________ Class 2 ________________
#
# ___
# 1)
# Added a sanity check to make sure that the stored num_tasks is correct
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Generate the rupture seed even if the GMF are not generated, to generate the same ruptures independently from the flag ground_motion_fields
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# The Monitor can now flush open hdf5 files
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Failed computations without a JobParam record must appear in the HTML report
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# The ReportWriter now manages the case of no write permission
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Do not change the rlz ordinal in get_efftive_rlzs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Now the engine server closes the datastore
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Raised an error when there is no risk IMT for a given hazard IMT
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Updated .received to be a list
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# init_performance can now work in swmr mode
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1268
# Most common committers:
# [('aaron.patterson@gmail.com', 120), ('blactbt@live.de', 97)]
# Most common project:
# ('saltstack_salt', 165)
#
#
#
# ________________ Class 3 ________________
#
# ___
# 1)
# Added a comment about monitoring postgres
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added check for missing area_source_discretization
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Added a warning for missing realizations
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed bug with .from_engine causing hazard maps not being plotted in disaggregation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Sorting the outputs by display_name
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Storing rlzs_by_grp
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Closed process pool after prefiltering
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Added a check for missing hazard curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Removed filtering from classical_tiling calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Added check for missing investigation_time
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 869
# Most common committers:
# [('P.Rudiger@ed.ac.uk', 65), ('aaron.patterson@gmail.com', 55)]
# Most common project:
# ('saltstack_salt', 81)
#
#
#
# ________________ Class 4 ________________
#
# ___
# 1)
# Restored parallel.Sequential correctly
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Reduced multi_fault.BLOCKSIZE
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Reduced the pmf.PRECISION
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed dependence from cost.TRT
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Rename a variable.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 6)
# Fixed a typo.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 7)
# Lazy load deferred services.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 8)
# Just a simple reorganization.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_notifier
# ___
# 9)
# fixed invalid method name.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_resources
# ___
# 10)
# Fixes a condition.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# _________________
#
# Number of messages in this class: 597
# Most common committers:
# [('postmodern.mod3@gmail.com', 194), ('crynobone@gmail.com', 93)]
# Most common project:
# ('ronin-ruby_ronin', 104)
#
#
#
# ________________ Class 5 ________________
#
# ___
# 1)
# Preserving the argument order in sap.Script
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Made workflows.Scenario consistent with the engine calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Use provider for consistent language.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 4)
# Remove alias from service provider.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 5)
# Change method visibility to adhere with parent class.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_view
# ___
# 6)
# Register package before boot.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_memory
# ___
# 7)
# Improves performance by swapping offsetGet with make.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_facile
# ___
# 8)
# Add load migration from.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 9)
# Avoid setting up test environment twice.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 10)
# Readd for backward compatibility.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# _________________
#
# Number of messages in this class: 988
# Most common committers:
# [('mark@mark-story.com', 195), ('taylorotwell@gmail.com', 172)]
# Most common project:
# ('cakephp_cakephp', 177)
#
#
#
# ________________ Class 6 ________________
#
# ___
# 1)
# Supported Django <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Compatibility with Django <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Renamed cross_idl->add<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed event_based_damage after <URL>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Accepted pyzmq <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# missing variable changes from <I>af<I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_resources
# ___
# 7)
# Fixes syntax for php <I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 8)
# Laravel update broke getDefaultDriver
#
# <URL>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_imagine
# ___
# 9)
# Fixes code for php <I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 10)
# Support both structure for <I> and <I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_api
# _________________
#
# Number of messages in this class: 1033
# Most common committers:
# [('igor.kroitor@gmail.com', 511), ('mike@silverorange.com', 108)]
# Most common project:
# ('ccxt_ccxt', 511)
#
#
#
# ________________ Class 7 ________________
#
# ___
# 1)
# Fixed an error happening when the memory stats are not available (None instead of an integer)
#
#
# Former-commit-id: <I>cbd<I>c<I>f4c7ba4dd<I>d8d2b0fdd
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# More work on calc_id <-> job_id
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Added task_ids management [skip CI]
#
#
# Former-commit-id: <I>a<I>db<I>c<I>ebdaac0
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Run RuptureGetter.get_eid_rlz sequentially if there are few sites [skip hazardlib]
#
#
# Former-commit-id: <I>ca<I>a5c<I>e2f6cbd<I>c1f<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Made the format more similar to the one used in oq-lite
#
#
# Former-commit-id: 6a4f<I>b4a9c8e<I>f0f<I>a<I>d<I>da<I>c<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Avoided restarting the pool in the tests [demos]
#
#
# Former-commit-id: f7f<I>a<I>dfcbee<I>ffadf6b7adfdddc
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Assumed len(all_jobs) >= 1
#
#
# Former-commit-id: ced3da8a4bf5c<I>aaea1af<I>b<I>d<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Return the traceback as a JSON always
#
#
# Former-commit-id: 5fc<I>ce<I>a3d<I>b6bd7bfda<I>ed<I>e1af1a
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Using Processmap for computing the statistical curves
#
#
# Former-commit-id: a<I>acefdf8d<I>bcb9bf0f<I>ba<I>f<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Restored an essential .init() [skip hazardlib]
#
#
# Former-commit-id: <I>abe<I>d7f7dcbb<I>c<I>dcef1da<I>ba7
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1179
# Most common committers:
# [('michele.simionato@gmail.com', 308), ('Lars.Butler@gmail.com', 264)]
# Most common project:
# ('gem_oq-engine', 572)
#
#
#
# ________________ Class 8 ________________
#
# ___
# 1)
# Fixed build_header doctest
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Make sure the exported zip files are compressed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Made sure DictArray is not empty
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed bug when rtree is missing
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Removed the dictionary outs which was unused
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Improved error message when the rupture mesh is too big
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# A small fix when the hazard calculation is not known
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Added a tests checking that setval is called correctly
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fixed bug when hcurves are not stored
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Fixed hazard_calculation_id not passed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1101
# Most common committers:
# [('ns@vivid-planet.com', 76), ('thatch45@gmail.com', 60)]
# Most common project:
# ('saltstack_salt', 119)
#
#
#
# ________________ Class 9 ________________
#
# ___
# 1)
# Rename to handle.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 2)
# Should be able to cache routes. Closes #2
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_installer
# ___
# 3)
# Append self to closure.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 4)
# Small tweak to test case.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 5)
# Allow to override the default sanitizer.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 6)
# Ignores failure to execute finish command.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_memory
# ___
# 7)
# Add helper to service provider.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_installer
# ___
# 8)
# Allow to get exceptions parameters.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 9)
# Passthrough request to check bank account.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 10)
# Tweak event fire to be consistent with v1.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# _________________
#
# Number of messages in this class: 723
# Most common committers:
# [('crynobone@gmail.com', 182), ('postmodern.mod3@gmail.com', 155)]
# Most common project:
# ('ronin-ruby_ronin', 67)
#
#
#
# ________________ Class 10 ________________
#
# ___
# 1)
# Assumed len(all_jobs) >= 1
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Changed one character _->. for clarity
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Remove actionColorForLevel.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 4)
# Use Discovery directly.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 5)
# Rename variable. #7
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_installer
# ___
# 6)
# Add Orchestra\Support\Contracts\CsvableInterface and Orchestra\Support\Collection.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 7)
# Support casting split_payment[fixed_cut].
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 8)
# Use make instead of offsetGet.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 9)
# Docblock and whitespace.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 10)
# utilize Illuminate\Support\Collection.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# _________________
#
# Number of messages in this class: 400
# Most common committers:
# [('postmodern.mod3@gmail.com', 177), ('jaraco@jaraco.com', 47)]
# Most common project:
# ('ronin-ruby_ronin', 100)
#
#
#
# ________________ Class 11 ________________
#
# ___
# 1)
# Fixed bug: the stats must be stored as a string, not an array of strings [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# If there are not calculations, an empty list is returned, not a NotFound
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Restored a += accidentally removed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Ssetting `hazard_calculation_id` in the job.ini is now possible
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Restored get_weight as it was [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Better error message if the shared_dir is not mounted [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed event_based/case_5 again (probably broken by a merge)
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Fixes "Only variables should be passed by reference" on travis.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 9)
# Ensure that $app['orchestra.installed'] is preserved between call.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 10)
# Return Illuminate\Support\Fluent when possible, this allow developer to further chain additional command such as ->after() etc.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   illuminate_database
# _________________
#
# Number of messages in this class: 1532
# Most common committers:
# [('pedro@algarvio.me', 88), ('ocramius@gmail.com', 83)]
# Most common project:
# ('saltstack_salt', 181)
#
#
#
# ________________ Class 12 ________________
#
# ___
# 1)
# Added a correction factor of <I> to point sources
#
#
# Former-commit-id: b9d6a<I>d<I>c<I>dc<I>ed6f3fc2ff<I>fe
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added a comment
#
#
# Former-commit-id: 1dcd<I>dad<I>d3df<I>e<I>fc<I>ff5fd<I>a6fef0
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small cleanup of oq check_input [skip CI]
#
#
# Former-commit-id: <I>ce<I>b<I>d<I>a<I>bc<I>c<I>ef<I>e9ea
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Reflected the change in the weighting algorithm
#
#
# Former-commit-id: 1b<I>e<I>fd<I>ec<I>a<I>ca<I>cf9d<I>e<I>f [formerly e<I>ec<I>afdb0dc6e3a<I>fdf<I>c<I>ca0ad<I>]
# Former-commit-id: eb<I>bd<I>c5f<I>c<I>cfea<I>e<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Removed a remaining reference to models.SiteCollection in the scenario calculator
#
#
# Former-commit-id: d<I>a<I>d<I>c1ec<I>f<I>c6b [formerly 1df<I>b0ff0d0e<I>a7f<I>faa<I>bb<I>f]
# Former-commit-id: 8fc<I>cbf9f8e<I>bd9a<I>ee<I>fcd<I>c<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added an useful Socket.__repr__
#
#
# Former-commit-id: ede<I>e<I>a<I>f<I>db1c<I>ba<I>a6aab<I>c0a2 [formerly 2d<I>c1de<I>a0e2b<I>cc<I>a<I>a<I>c<I>c]
# Former-commit-id: e9ab<I>e9aa3e<I>f5f<I>c<I>a<I>aa<I>bd3
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Restored dask support
#
#
# Former-commit-id: <I>a6b6e<I>e6bbe7ab<I>b8dfc<I>dd<I>ba2 [formerly f8dc<I>e<I>f3c<I>f<I>a0f3f8f2c<I>]
# Former-commit-id: b8d9d8b<I>f5ad<I>eb<I>c<I>fefba<I>c4dd5d
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Removed obsolete function
#
#
# Former-commit-id: c<I>c<I>a3d<I>f5a<I>c<I>b2de1dc1aed<I>a4a
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Make sure there is rupture-filtering in the scenario calculator
#
#
# Former-commit-id: <I>b<I>c<I>c<I>e7c0d<I>c<I>bb<I>d3a8
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Fix in the workerpool [skip CI]
#
#
# Former-commit-id: ff5f4c<I>cfdc<I>d<I>b<I>b<I>a<I>a<I>c<I> [formerly <I>b<I>bf<I>fcdd6f4d<I>afbea<I>e<I>]
# Former-commit-id: d<I>d<I>cfbc<I>db<I>aa<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1859
# Most common committers:
# [('michele.simionato@gmail.com', 1487), ('Lars.Butler@gmail.com', 216)]
# Most common project:
# ('gem_oq-engine', 1703)
#
#
#
# ________________ Class 13 ________________
#
# ___
# 1)
# Hide the SES output from a scenario calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Compare floats within the relative tolerance
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Simplified the LOG_FORMAT by removing the name
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Changed the export order for the event_loss_table
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Added the path to the decorator module in the virtual file path
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   micheles_decorator
# ___
# 6)
# Hiding the avg_gmf output
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Temporary change to let pass an empty test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Update the scenario calculator to the new API
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Moved the sanity check on the log file that was giving a false warning
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Improved the info command to show info about the input/output weights
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1175
# Most common committers:
# [('blactbt@live.de', 274), ('thatch45@gmail.com', 191)]
# Most common project:
# ('meew0_discordrb', 272)
#
#
#
# ________________ Class 14 ________________
#
# ___
# 1)
# Reflected a small change of API in commonlib.parallel.PerformanceMonitor
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Changed self.N to be the number of filtered sites
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Removed the last reference to .calc_id
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed a reference to /tmp
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Removed a remaining reference to models.SiteCollection in the scenario calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Ordered the ruptures by grp_id
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Small fix to the TaskManager.progress
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Raised an error for soil_intensities with amplification_method != convolution
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Used a weakref.WeakSet just to stay on the safe side against memory leaks
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Add some odd test due to funkiness of static macro.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# _________________
#
# Number of messages in this class: 1182
# Most common committers:
# [('postmodern.mod3@gmail.com', 454), ('jaraco@jaraco.com', 129)]
# Most common project:
# ('ronin-ruby_ronin', 245)
#
#
#
# ________________ Class 15 ________________
#
# ___
# 1)
# add Content::PUBLISHED_AT constant.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 2)
# Replace HS with laravie/dhosa.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 3)
# Pass instance of filesystem.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_studio
# ___
# 4)
# Reworks on contract.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 5)
# Allow Orchestra\Foundation\Services\UserMetaRepository to look for data from eloquent before resolving to default. Closes orchestral/control#<I>.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Add caret for dropdown.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 7)
# Forward request to InteractsWithQueue.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 8)
# Improves notifications binding.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 9)
# Interacts with time.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 10)
# Require csrf token for logout.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# _________________
#
# Number of messages in this class: 736
# Most common committers:
# [('postmodern.mod3@gmail.com', 305), ('crynobone@gmail.com', 97)]
# Most common project:
# ('ronin-ruby_ronin', 137)
#
#
#
# ________________ Class 16 ________________
#
# ___
# 1)
# Improved comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Refined weight [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed leftover lines [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed logging [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed sanity check [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed too many aggregations error [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Removed empty line [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Improved comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Added comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 546
# Most common committers:
# [('fabien.potencier@gmail.com', 273), ('michele.simionato@gmail.com', 160)]
# Most common project:
# ('symfony_symfony', 244)
#
#
#
# ________________ Class 17 ________________
#
# ___
# 1)
# Changed r_sites -> s_sites
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixes running `php artisan extension:refresh` shouldn't reset handles
# value. Closes #<I>.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 3)
# Add <!—more—> tag to create excerpt.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 4)
# Update testcase based on laravel/framework@1d<I> changes
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 5)
# shared/validate: Makes IsUint<I> non-optional
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# shared/validate/validate: Fix bug in ParseUint<I>Range
#
# The range size of <I>-<I> is 2 not 1.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/util/http: Use net.JoinHostPort in ListenAddresses rather than wrapping IPv6 addresses in []
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/network/network/utils: Check end port is higher than start port in ParsePortRange
#
# Prevents ranges like `<I>-<I>` and `<I>-<I>`.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/api/<I>: Updates readStoragePoolDriversCache usage and populates env.StorageSupportedDrivers
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# container/lxc: Ensure if bridge nic added/removed that dnsmasq config is refreshed
#
# Fixes #<I>
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 938
# Most common committers:
# [('none@none', 285), ('hajimehoshi@gmail.com', 134)]
# Most common project:
# ('hajimehoshi_ebiten', 130)
#
#
#
# ________________ Class 18 ________________
#
# ___
# 1)
# Remove publisher/ftp
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 2)
# lxd/cluster/gateway: Add HeartbeatOfflineThreshold var
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 3)
# lxd/networks: d.cluster.GetNetworkInAnyState usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# lxd/storage/utils: drivers.NewVolume usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# lxd/daemon: db.OpenCluster usage in init
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# lxd/images: Comment weaks
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/util/net: Improve comment in CanonicalNetworkAddress
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/images: Updates autoUpdateImage to use d.ImageDownload
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/events: d.events.AddListener usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/device/disk: Consistent comment line endings
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 728
# Most common committers:
# [('thomas.parrott@canonical.com', 407), ('stgraber@ubuntu.com', 212)]
# Most common project:
# ('lxc_lxd', 619)
#
#
#
# ________________ Class 19 ________________
#
# ___
# 1)
# Refactored a bit boore_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added an if bb
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small cleanup in build_asset_array
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed the _slots_ bug with RuptureCollectionSource
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Force a single branching level[demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Some work on SourceModelLogicTree.__fromh5__ [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed bug in the SourceFilter when calling SiteCollection.filtered [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Forbidden grid and sites at the same time [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Support for old engine in gsim_lt.__fromh5__ [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# [<I>] Generate a URL to an application asset from a root domain such as CDN etc.
#
# This would simplify generating asset when you need to specify different root domain/url as the request. Alternative to laravel/framework#<I> PR.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# _________________
#
# Number of messages in this class: 2123
# Most common committers:
# [('mike@silverorange.com', 265), ('blickly@google.com', 261)]
# Most common project:
# ('silverorange_swat', 264)
#
#
#
# ________________ Class 20 ________________
#
# ___
# 1)
# Added a minimum task_duration of <I> seconds [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Storing disagg_by_src always [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Not computing avg_gmf over <I> MB [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed zeros in view_delta_loss [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Hack for CHN model [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Measuring memory in computing_risk [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Importing networkx on demand [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Storing the vulnerability functions at <I> bit [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Raised the timeout again [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Fixed make_figure_disagg for Mag_Dist [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 674
# Most common committers:
# [('marijnh@gmail.com', 105), ('ccordoba12@gmail.com', 86)]
# Most common project:
# ('codemirror_CodeMirror', 93)
#
#
#
# ________________ Class 21 ________________
#
# ___
# 1)
# Added Content-Length to WebUI outputs [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed OpenQuake logo in the Advanced Manual
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed mosaic tests for USA and UCF
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Added Effective Amplitude Spectrum (EAS) IMT
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Added constants LOSSTYPE, LTI
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Implemented the Goda-Atkinson cross correlation model
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Tweak Credential and Register controller filter.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 8)
# Update extension, kernel and support file lists.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 9)
# Update Laravel 7 skeleton.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 10)
# client/lxd/server: Initialise websocket event listeners and connections in UseProject and UseTarget
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 262
# Most common committers:
# [('jerome@leclan.ch', 68), ('matijs@matijs.net', 23)]
# Most common project:
# ('jleclanche_fireplace', 56)
#
#
#
# ________________ Class 22 ________________
#
# ___
# 1)
# Fixed openquake/engine/tests/calculators/hazard/post_processing_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed hazardlib/tests/calc/stochastic_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Add Orchestra/Html/Form/Field and Orchestra/Html/Table/Column
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 4)
# lxd/instance/drivers/driver/qemu: Add input checks to addDriveConfig
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# lxd/storage/pools/utils: Comment on storagePoolDBCreate
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# lxd/storage/drivers/driver/btrfs/volumes: Adds safety net against failed matching of subvolumes
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/main/init/interactive: Error wrapping
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/device/nic/physical: SetMTU usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/storage/backend/mock: Adds Description, Status and LocalStatus functions
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/storage/drivers/driver/btrfs/volumes: Ensure subvolumes in snapshots are copied during CreateVolumeFromCopy
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 1118
# Most common committers:
# [('thomas.parrott@canonical.com', 903), ('stgraber@ubuntu.com', 70)]
# Most common project:
# ('lxc_lxd', 973)
#
#
#
# ________________ Class 23 ________________
#
# ___
# 1)
# Improved SiteCollection.__doc__ [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# [<I>] Add missing import
#
# Fixes failing $this->assertViewHas() and $this->assertViewHasAll().
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_framework
# ___
# 3)
# bpo-<I>: Support macOS <I> and Apple Silicon (GH-<I>)
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   pypa_setuptools
# ___
# 4)
# Added the :buffer type (ex: [:buffer, <I>]).
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin-support
# ___
# 5)
# Added Task#exclude_ports (closes #<I>).
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   sophsec_ruby-nmap
# ___
# 6)
# Lessen references to Arch.i<I>, etc.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin
# ___
# 7)
# Added unix_server_loop (issue #<I>).
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin-support
# ___
# 8)
# Oops, should be <I> characters, not <I>.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   robbyrussell_shorturl
# ___
# 9)
# Added tcp_server_loop (issue #<I>).
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin-support
# ___
# 10)
# [Comments] Only send the comments notification once (#<I>)
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# _________________
#
# Number of messages in this class: 791
# Most common committers:
# [('taylor@laravel.com', 451), ('taylorotwell@gmail.com', 66)]
# Most common project:
# ('laravel_framework', 322)
#
#
#
# ________________ Class 24 ________________
#
# ___
# 1)
# Avoided division by zero in _get_poes
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Avoid numpy warnings caused by log(0) in classical_damage
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed calculation of statistics in classical_risk [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed .smweight in read_input
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Stored rlzs_by_grp as 2D arrays when possible [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added _slots_ to RuptureCollectionSource
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed bug in DiscreteDistribution introduced yesterday [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Improve code coverage based on <I> commit.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 9)
# Fixed event names on registration
#
# creating > created
# saving > saved
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 10)
# client/events: Get lock before checking e.disconnected in Disconnect
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 595
# Most common committers:
# [('skodak', 493), ('igor.kroitor@gmail.com', 13)]
# Most common project:
# ('moodle_moodle', 506)
#
#
#
# ________________ Class 25 ________________
#
# ___
# 1)
# Remove rlzs_assoc when prefilter is False
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Not using Django when deleting calculations
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Not returning the avg_losses when not wanted
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed a bug when zipping files with [reqv]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Open the DataStore in read mode when exporting
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Reduced the precision when exporting GMFs to XML
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Reduced the precision when exporting the loss curves in CSV
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Fixed a bug when saving the performance
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Special case when saving GSIMs into the database
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Avoided negative small numbers when computing the std
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 726
# Most common committers:
# [('ccordoba12@gmail.com', 81), ('p@shedcollective.org', 60)]
# Most common project:
# ('spyder-ide_spyder', 80)
#
#
#
# ________________ Class 26 ________________
#
# ___
# 1)
# Added __wrapped__ even to the high level usage of decorator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   micheles_decorator
# ___
# 2)
# Fixed so that the number of bytes sent to the workers is stored [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Remove the loss_curve_resolution default, since it is done in commonlib.readinput
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Restored the AreaSource.RUPTURE_WEIGHT as it was
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Made it possible to run risk on top on another user hazard again [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Test applyToSources for a source that does not exist in the given branch [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Logged a not implemented error for rupture_slip_direction
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Saved the loss ratios also in event_based_risk
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fill sig and eps with NaNs when it is the case [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Removing return inside ExceptionHandler
#
# Removing a return that is not needed.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# _________________
#
# Number of messages in this class: 2508
# Most common committers:
# [('palehose@gmail.com', 256), ('mark@mark-story.com', 234)]
# Most common project:
# ('saltstack_salt', 479)
#
#
#
# ________________ Class 27 ________________
#
# ___
# 1)
# Update docblock.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 2)
# Simplify condition.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_webhook
# ___
# 3)
# Update contract.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_model
# ___
# 4)
# Update docblock.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 5)
# Update comment.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 6)
# Update construct docblock.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 7)
# Add docblock.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 8)
# Update contract.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_memory
# ___
# 9)
# Update trait.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_notifier
# ___
# 10)
# Update deps.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_model
# _________________
#
# Number of messages in this class: 223
# Most common committers:
# [('crynobone@gmail.com', 222), ('matijs@matijs.net', 1)]
# Most common project:
# ('orchestral_foundation', 32)
#
#
#
# ________________ Class 28 ________________
#
# ___
# 1)
# Update QueryFilter.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 2)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_parser
# ___
# 3)
# Update MailConfigurationUpdater.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 4)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 5)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 6)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 7)
# Reword.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 8)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   katsana_katsana-sdk-php
# ___
# 9)
# Fixes CS.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_api
# ___
# 10)
# Fixes EOF.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# _________________
#
# Number of messages in this class: 103
# Most common committers:
# [('crynobone@gmail.com', 98), ('postmodern.mod3@gmail.com', 1)]
# Most common project:
# ('jomweb_billplz', 9)
#
#
#
# ________________ Class 29 ________________
#
# ___
# 1)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 2)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 3)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 4)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 5)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_framework
# ___
# 6)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 7)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 8)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 9)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 10)
# wip
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# _________________
#
# Number of messages in this class: 98
# Most common committers:
# [('crynobone@gmail.com', 97), ('mark@mark-story.com', 1)]
# Most common project:
# ('orchestral_testbench-core', 53)
#
#
#
# ________________ Class 30 ________________
#
# ___
# 1)
# Refactored toro_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Vectorized climent_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Supporting h5py <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Support for Django >= <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Reverted to h5py <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Use <URL>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 7)
# Use <br> instead of <p>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 8)
# [<I>] Add missing import.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_dusk
# ___
# 9)
# Workaround <URL>
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_jaraco.clipboard
# ___
# 10)
# Restore Python <I> syntax in setup.py. Fixes #<I>.
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_hgtools
# _________________
#
# Number of messages in this class: 513
# Most common committers:
# [('koenkanters94@gmail.com', 451), ('avwu@qq.com', 12)]
# Most common project:
# ('Koenkk_zigbee-shepherd-converters', 451)
#
#
#
# ________________ Class 31 ________________
#
# ___
# 1)
# Added missing [directory] in the openquake.cfg generate by install.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Renamed a title of the report [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Removed the check on too many aggregation tags [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Logging the heavy sources [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# ...
# Project:   orchestral_support
# ___
# 7)
# Cleanup requirement.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_installer
# ___
# 8)
# Tweak code.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 9)
# Small fixes.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 10)
# Fixed variable name.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# _________________
#
# Number of messages in this class: 187
# Most common committers:
# [('crynobone@gmail.com', 169), ('postmodern.mod3@gmail.com', 8)]
# Most common project:
# ('orchestral_foundation', 41)
#
#
#
# ________________ Class 89 ________________
#
# ___
# 1)
# Refactored Socket.__iter__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Not removing __pyclass__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Improved File.__fromh5__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed a serious bug in ProbabilityMap.__or__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Solved a very tricky bit with __nonzero__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Used humansize in the __repr__ of the Monitor class
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Small enhancement to IntegrationDistance.__call__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Fixed _submit_many
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Optimized ProbabilityMap.__iadd__ further
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Improved the __repr__ of the monitor
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 376
# Most common committers:
# [('pedro@algarvio.me', 108), ('jaraco@jaraco.com', 30)]
# Most common project:
# ('saltstack_salt', 147)
#
#
#
# ________________ Class 90 ________________
#
# ___
# 1)
# Splitting in homogeneous tiles
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restored sequential calculations of the loss maps
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Start the zworkers at DbServer startup only in production releases
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Improved the check on duplicated points
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fix a missing argument for classical risk statistics
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Minor compatibility fix with the SMTK
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Added a CSV exporter for aggregated loss curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Added two other docstrings
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Small fix in calc_stats
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Raise an error for wrong time events
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 847
# Most common committers:
# [('P.Rudiger@ed.ac.uk', 91), ('moodler', 51)]
# Most common project:
# ('pyviz_holoviews', 86)
#
#
#
# ________________ Class 91 ________________
#
# ___
# 1)
# Fixed  qa_tests/hazard/event_based/spatial_correlation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed a bug in risk/validation.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed formatting of the author/name and author/email tags.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin
# ___
# 4)
# Added @see tags for initialize_sanitizers, initialize_filters, initialize_actions, initialize_events.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   postmodern_spidr
# ___
# 5)
# added params to load_markets/fetch_markets in python/ccxt/base/exchange.py
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 6)
# this.trades = array/list
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 7)
# qryptos/quoine + fetch2
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 8)
# Drop Py2 and six on salt/modules/debian_ip.py
#
# - - -
# Committer: pedro@algarvio.me
# Project:   saltstack_salt
# ___
# 9)
# Drop Py2 and six on salt/beacons/ps.py
#
# - - -
# Committer: pedro@algarvio.me
# Project:   saltstack_salt
# ___
# 10)
# Drop Py2 and six on salt/states/logadm.py
#
# - - -
# Committer: pedro@algarvio.me
# Project:   saltstack_salt
# _________________
#
# Number of messages in this class: 254
# Most common committers:
# [('pedro@algarvio.me', 237), ('igor.kroitor@gmail.com', 3)]
# Most common project:
# ('saltstack_salt', 240)
#
#
#
# ________________ Class 92 ________________
#
# ___
# 1)
# Added view portfolio_damage_error
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Add missing ;
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 3)
# container/lxc: Fix description
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# shared/validate: Adds IsNetworkVLAN
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# shared/validate: Adds IsURLSegmentSafe function
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# shared/instance: Improves comments
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# client/operations: Race fix
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# shared/util: Adds IsTrueOrEmpty function
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# shared/idmap: Adds JSONMarshal function
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# container: Removes migrated infiniband validation
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 544
# Most common committers:
# [('hajimehoshi@gmail.com', 163), ('duncan.macleod@ligo.org', 91)]
# Most common project:
# ('hajimehoshi_ebiten', 159)
#
#
#
# ________________ Class 93 ________________
#
# ___
# 1)
# Remove a .flatten not used anymore
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Change .read_df to return strings and not bytes
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Do not ask for confirmation if there is nothing to do
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Do not collapse for nontrivial dip
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Do not renumber the TRTModels
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# The investigationTime attribute does not appear when zero
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Don't export from the datastore
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Do not stop the zworkers when it is dangerous to do so
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Removed a feature that we do not want to support
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# macos and windows do not support multi_user
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 926
# Most common committers:
# [('ns@vivid-planet.com', 127), ('thatch45@gmail.com', 69)]
# Most common project:
# ('saltstack_salt', 175)
#
#
#
# ________________ Class 94 ________________
#
# ___
# 1)
# Make queue.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_notifier
# ___
# 2)
# Simplify import.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 3)
# Use private.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_codex
# ___
# 4)
# Update tests.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_ringgit
# ___
# 5)
# Simplify loading routes.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Use make or fallback.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# ___
# 7)
# Update tests.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 8)
# Use static.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 9)
# Allow null.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   katsana_katsana-sdk-php
# ___
# 10)
# Simplify fetching configuration.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# _________________
#
# Number of messages in this class: 253
# Most common committers:
# [('crynobone@gmail.com', 236), ('jaraco@jaraco.com', 4)]
# Most common project:
# ('orchestral_foundation', 36)
#
#
#
# ________________ Class 95 ________________
#
# ___
# 1)
# Changed the default job status to 'executing' (was 'pre_executing')
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Reduced number of "no data" logging messages
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Restored the old "order by" in individual_curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed hack for "database is locked"
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Backend routes should always use the "web" middleware group.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Form::select with placeholder should use 'disabled'
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_html
# ___
# 7)
# Ensure "connection" config persist.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 8)
# Disallow reserve word "guest".
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 9)
# Rely on presence of 'error' element to detect errors.
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_wolframalpha
# ___
# 10)
# Derive 'clean' from expectedLines
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_path.py
# _________________
#
# Number of messages in this class: 770
# Most common committers:
# [('jmettraux@gmail.com', 170), ('tj@vision-media.ca', 50)]
# Most common project:
# ('floraison_flor', 137)
#
#
#
# ________________ Class 96 ________________
#
# ___
# 1)
# Ported more GMPE tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed the disagg QA tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Ported some GMPE test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Introduced function valid.namelists
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Enforced the num_cores limitation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Ported more GMPE tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Added openquake.calculators tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Ported some GMPE test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Ported some GMPE test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Monitored building riskinputs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 458
# Most common committers:
# [('igor.kroitor@gmail.com', 88), ('P.Rudiger@ed.ac.uk', 52)]
# Most common project:
# ('ccxt_ccxt', 88)
#
#
#
# ________________ Class 97 ________________
#
# ___
# 1)
# Add monitor support to litetasks
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Changed calcgmfs to accept multiple seeds
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small fix to the RecordBuilder to manage string fields
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Switched the default distance from rjb to rrup
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Changed OqParam.cross_correl to return None for NoCorrelation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Refactored the risk calculators to work by taxonomy
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Passed exports to Calculator.export
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Small fix to make_html_report
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Microfix to CallableDict keymissing
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Trying to fix latex encoding
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 944
# Most common committers:
# [('thatch45@gmail.com', 183), ('ben.gyori@gmail.com', 99)]
# Most common project:
# ('saltstack_salt', 301)
#
#
#
# ________________ Class 98 ________________
#
# ___
# 1)
# fix: get method name without the DataSet
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 2)
# devices/validate: Updates validation to understand infiniband has nictype
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 3)
# device: Links up disk device
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# container: Adds access to containerLoadByProjectAndName function from device package
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# device: Links up infiniband device
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# client/util: Update urlsToResourceNames to reduce allocations
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# container: Adds DeviceEventHandler to interface
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxc/remote: Update usage of CLI askers to handle errors
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# container/lxc: Ensure that sriov devices use volatile host_name for removal
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# client/util: Add timeouts to unixHTTPClient
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 915
# Most common committers:
# [('avwu@qq.com', 181), ('ccordoba12@gmail.com', 143)]
# Most common project:
# ('avwo_whistle', 179)
#
#
#
# ________________ Class 99 ________________
#
# ___
# 1)
# Added attribute .epsilons=None
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restored risk_imtls
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Support soil_levels=None
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Improve testcase
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 5)
# Remove unused code
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Add use Illuminate\Foundation\Publishing\AssetPublisher
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_publisher
# ___
# 7)
# Defer the CommandServiceProvider
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 8)
# Update facile classes rename
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 9)
# Update collision
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 10)
# Add missing IoC.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# _________________
#
# Number of messages in this class: 156
# Most common committers:
# [('crynobone@gmail.com', 38), ('jmettraux@gmail.com', 15)]
# Most common project:
# ('ccxt_ccxt', 14)

# %% [markdown]
# A kmeans model was trained on the vectors spacy calculates for each document.
#
# This clustering approach can detect some commonalities in between the commit messages. For example, in one cluster all messages include the tag &lt;I>, in others there is always something that is fixed, some always have an URL or a file path and also lengths and sentence structure can be equal in classes sometimes.
#
# That is why one could argue that messages in one resulting cluster of k-means should have approximately equal quality.

# %% [markdown]
# Idea: Use the "Elbow method" to calculate the best fitting number of cluster centers.
#
# https://github.com/Hassaan-Elahi/Writing-Styles-Classification-Using-Stylometric-Analysis
