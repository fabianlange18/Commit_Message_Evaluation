# %% [markdown]
# # K-Means Clustering Approach

# %% [markdown]
# #### Load Data and spaCy Model

# %% [markdown]
# Execute this block for all data:

# %%
import pandas as pd

# %%
data = pd.read_csv("results.csv")

# %% [markdown]
# Execute this block for the Frequent Committers Subset:

# %%
data = pd.read_pickle('Frequent_Committer_Subset')

# %%
data.head(3)
# Out:
#                                              message  \
# 0  Fixed an error happening when the memory stats...
# 1                         Updated setup.py [skip CI]
# 2            Fixed an exposure test [skip hazardlib]
#
#                committer_email             project
# 0  michele.simionato@gmail.com       gem_oq-engine
# 1  michele.simionato@gmail.com  micheles_decorator
# 2  michele.simionato@gmail.com       gem_oq-engine

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Take a Subset

# %%
subset_size = 100000

messages = data["message"][:subset_size].tolist()

# %% [markdown]
# #### Build Document Vectors

# %%
vectors = []

docs = nlp.pipe(messages)

for doc in docs:
    vectors.append(doc.vector)

# %% [markdown]
# ## Clustering the Subset with K-Means

# %% [markdown]
# #### Training

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(100)
kmeans.fit(vectors)
kmeans_prediction = kmeans.predict(vectors)

# %% [markdown]
# #### Evaluation

# %%
from collections import Counter

for label in range(kmeans.n_clusters):
    print("\n________________ Class " + str(label) + " ________________\n")
    class_counter = 1
    committer_emails = []
    projects = []
    print_examples = True
    for i, message in enumerate(messages):
        if class_counter == 11:
            print_examples = False
        if kmeans_prediction[i] == label:
            committer_emails.append(data["committer_email"][i])
            projects.append(data["project"][i])
            if print_examples:
                print("___")
                print(str(class_counter) + ") ")
                print(messages[i] + "\n")
                print("- - - ")
                print("Committer: " + str(data["committer_email"][i]))
                print("Project:   " + str(data["project"][i]))
            class_counter += 1
    print("_________________")
    print()
    print("Number of messages in this class: " + str(class_counter - 1))
    print("Most common committers:")
    print(Counter(committer_emails).most_common(2))
    print("Most common project:")
    print(Counter(projects).most_common(1)[0])
    print()
    print()
# Out:
# ________________ Class 0 ________________
#
# ___
# 1)
# Cleaned up /tmp in datastore test_read
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Only display menu when user has access.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 3)
# Handle binding ImagineInterface as well.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_imagine
# ___
# 4)
# remove register installer, no longer applicable.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 5)
# Ignore search by identifier if it's empty.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_authen
# ___
# 6)
# Use v-cloak until page is ready.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 7)
# Load relationship when available.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_model
# ___
# 8)
# Check if method exists.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 9)
# Add fullname validation if it's presented.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 10)
# Fuck yeah we now using static...
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# _________________
#
# Number of messages in this class: 1140
# Most common committers:
# [('postmodern.mod3@gmail.com', 166), ('mark@mark-story.com', 158)]
# Most common project:
# ('cakephp_cakephp', 149)
#
#
#
# ________________ Class 1 ________________
#
# ___
# 1)
# Removed an obsolete namedtuple
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Trapped only the DataStoreExportError
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Added a missing autoflush
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Added an error MissingExporter
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed a bug in ProbabilityMap.extract
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added a comment to a test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed the case of missing rtree
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Added a couple of asserts
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Sorted the GSIMs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Removed a pdb accidentally committed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 469
# Most common committers:
# [('michele.simionato@gmail.com', 261), ('moodler', 28)]
# Most common project:
# ('gem_oq-engine', 278)
#
#
#
# ________________ Class 2 ________________
#
# ___
# 1)
# Changed r_sites -> s_sites
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restore as it was [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixes running `php artisan extension:refresh` shouldn't reset handles
# value. Closes #<I>.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 4)
# Illuminate\Support\Str::title() is implemented, remove duplicate method. Closes #<I>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 5)
# Update testcase based on laravel/framework@1d<I> changes
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# lxd/instance/drivers: Write out updated backup.yaml after rename
#
# Fixes #<I>
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# shared/validate/validate: Fix bug in ParseUint<I>Range
#
# The range size of <I>-<I> is 2 not 1.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/network/network/utils: Check end port is higher than start port in ParsePortRange
#
# Prevents ranges like `<I>-<I>` and `<I>-<I>`.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/device/nic/sriov: Don't fail when resetting VF MAC to <I>:<I>:<I>:<I>:<I>:<I>
#
# Apparently the bnx2x devices don't allow this.
#
# Fixes #<I>
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# container/lxc: Ensure if bridge nic added/removed that dnsmasq config is refreshed
#
# Fixes #<I>
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 993
# Most common committers:
# [('none@none', 347), ('hajimehoshi@gmail.com', 143)]
# Most common project:
# ('vmalloc_dessert', 145)
#
#
#
# ________________ Class 3 ________________
#
# ___
# 1)
# Improved dbapi.Table
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Make queue.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_notifier
# ___
# 3)
# Create two application.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 4)
# Use container variable.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_view
# ___
# 5)
# Tweak some setup.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 6)
# Use private.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_codex
# ___
# 7)
# add missing import.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 8)
# Add assetic helper.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# Optimize basePath usage.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 10)
# Remove unused method.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# _________________
#
# Number of messages in this class: 532
# Most common committers:
# [('crynobone@gmail.com', 416), ('mark@mark-story.com', 18)]
# Most common project:
# ('orchestral_foundation', 67)
#
#
#
# ________________ Class 4 ________________
#
# ___
# 1)
# Not using Django when deleting calculations
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed a bug when zipping files with [reqv]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Open the DataStore in read mode when exporting
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Reduced the precision when exporting GMFs to XML
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Reduced the precision when exporting the loss curves in CSV
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Fixed a bug when saving the performance
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Special case when saving GSIMs into the database
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Avoided negative small numbers when computing the std
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fixed an issue when building the loss curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Improved error message when instantiating the CatalogueParser with a non-existing file
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 730
# Most common committers:
# [('ccordoba12@gmail.com', 97), ('p@shedcollective.org', 60)]
# Most common project:
# ('spyder-ide_spyder', 96)
#
#
#
# ________________ Class 5 ________________
#
# ___
# 1)
# Avoided division by zero in _get_poes
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Avoid numpy warnings caused by log(0) in classical_damage
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed calculation of statistics in classical_risk [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Stored rlzs_by_grp as 2D arrays when possible [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed bug in DiscreteDistribution introduced yesterday [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Fixed the bug with missing TRTs affecting KOR, SEA[skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Improve code coverage based on <I> commit.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 8)
# Fixed event names on registration
#
# creating > created
# saving > saved
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# Fixed test failures in iter_
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_jaraco.util
# ___
# 10)
# Restore Python <I> compatibility where with statements were used
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_hgtools
# _________________
#
# Number of messages in this class: 588
# Most common committers:
# [('skodak', 497), ('igor.kroitor@gmail.com', 15)]
# Most common project:
# ('moodle_moodle', 508)
#
#
#
# ________________ Class 6 ________________
#
# ___
# 1)
# Changed the default job status to 'executing' (was 'pre_executing')
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Reduced number of "no data" logging messages
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Restored the old "order by" in individual_curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed hack for "database is locked"
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Backend routes should always use the "web" middleware group.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Form::select with placeholder should use 'disabled'
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_html
# ___
# 7)
# Ensure "connection" config persist.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 8)
# Disallow reserve word "guest".
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 9)
# shared/instance: Adds ConfigVolatilePrefix constant
#
# To avoid inconsistent use of "volatile" and "volatile." prefix checks.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# Rely on presence of 'error' element to detect errors.
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_wolframalpha
# _________________
#
# Number of messages in this class: 756
# Most common committers:
# [('jmettraux@gmail.com', 177), ('tj@vision-media.ca', 47)]
# Most common project:
# ('floraison_flor', 142)
#
#
#
# ________________ Class 7 ________________
#
# ___
# 1)
# Ordered the ruptures by grp_id
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Reduced the pmf.PRECISION
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# add Content::PUBLISHED_AT constant.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 4)
# Replace HS with laravie/dhosa.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 5)
# Pass instance of filesystem.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_studio
# ___
# 6)
# Reworks on contract.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 7)
# Allow Orchestra\Foundation\Services\UserMetaRepository to look for data from eloquent before resolving to default. Closes orchestral/control#<I>.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 8)
# Add caret for dropdown.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 9)
# Forward request to InteractsWithQueue.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 10)
# Interacts with time.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# _________________
#
# Number of messages in this class: 766
# Most common committers:
# [('postmodern.mod3@gmail.com', 326), ('crynobone@gmail.com', 88)]
# Most common project:
# ('ronin-ruby_ronin', 146)
#
#
#
# ________________ Class 8 ________________
#
# ___
# 1)
# Added check on applyToBranches together with applyToSources [demos][skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Sanity check against negative differences in pairwise_diff [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Stripped duplicates in view_task_info
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Reimplemented classical_risk in terms of regula tasks [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Produce more tasks in the case of few sites [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Resync configuration on setting update, part of #9.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 7)
# client/interfaces: Adds Name field to StoragePoolVolumeBackupArgs to bring in line with InstanceBackupArgs
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/network: Adds LoadBalancers field to Info and enables it for OVN networks
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/images: Updates imageCreateInPool to use EnsureImage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/storage/utils: Validates volatile.rootfs.size key for image volumes in validateVolumeCommonRules
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 761
# Most common committers:
# [('duncan.macleod@ligo.org', 189), ('ccordoba12@gmail.com', 99)]
# Most common project:
# ('gwpy_gwpy', 189)
#
#
#
# ________________ Class 9 ________________
#
# ___
# 1)
# Refactored toro_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed event_based_damage after <URL>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Vectorized climent_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Supporting h5py <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Support for Django >= <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Reverted to h5py <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Use <URL>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 8)
# Use <br> instead of <p>
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# [<I>] Add missing import.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_dusk
# ___
# 10)
# Workaround <URL>
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_jaraco.clipboard
# _________________
#
# Number of messages in this class: 529
# Most common committers:
# [('koenkanters94@gmail.com', 458), ('igor.kroitor@gmail.com', 16)]
# Most common project:
# ('Koenkk_zigbee-shepherd-converters', 458)
#
#
#
# ________________ Class 10 ________________
#
# ___
# 1)
# Duplicated git_suffix from hazardlib
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added a sorted(s.grp_id for s in srcs)
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Set BaseSource.weight to 0
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Turn the task queue from LIFO to FIFO
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Refactoring of AssetCollection.values
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Moved some code into engine.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Monitoring iter_ruptures in UCERF
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Restored delta in DisaggregationTestCase
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fixed make_html_report to work with SQLite
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Stored task_no in gmftimes
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 618
# Most common committers:
# [('P.Rudiger@ed.ac.uk', 101), ('igor.kroitor@gmail.com', 89)]
# Most common project:
# ('pyviz_holoviews', 95)
#
#
#
# ________________ Class 11 ________________
#
# ___
# 1)
# Errors should never be silenced
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Change .read_df to return strings and not bytes
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Do not ask for confirmation if there is nothing to do
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Do not collapse for nontrivial dip
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Do not renumber the TRTModels
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Don't export from the datastore
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Do not stop the zworkers when it is dangerous to do so
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Removed a feature that we do not want to support
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# macos and windows do not support multi_user
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Do not store relevant_events when there is no minimum_intensity
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 722
# Most common committers:
# [('ns@vivid-planet.com', 83), ('pedro@algarvio.me', 54)]
# Most common project:
# ('saltstack_salt', 130)
#
#
#
# ________________ Class 12 ________________
#
# ___
# 1)
# Relaxed the case_master tests with a delta of 1E-5
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Managed the case of data already saved in the cache file
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed a bug when exporting the hazard curves in the case of GMPETable
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Simplified the header of numpy arrays in rst_table
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed the test for probabilities equal to zero
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Reflected the change in SiteCollection.from_points
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Raised the tolerance of the assert in scientific.mean_curve
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# I fix the management of job.status
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Changed the serialization of ruptures
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Displayed information about the size of the hazard curves
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1133
# Most common committers:
# [('michele.simionato@gmail.com', 218), ('blactbt@live.de', 82)]
# Most common project:
# ('gem_oq-engine', 226)
#
#
#
# ________________ Class 13 ________________
#
# ___
# 1)
# Improved comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Refined weight [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed leftover lines [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed logging [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed sanity check [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Fixed too many aggregations error [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Removed empty line [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Storing disagg_by_src always [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Improved comment [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 624
# Most common committers:
# [('fabien.potencier@gmail.com', 289), ('michele.simionato@gmail.com', 178)]
# Most common project:
# ('symfony_symfony', 257)
#
#
#
# ________________ Class 14 ________________
#
# ___
# 1)
# Refactored a bit boore_<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restored build_loss_maps as it was [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Now event_based honor the concurrent_tasks in all cases [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Fixed a call to mock.Mock to be backward compatible up to Ubuntu <I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Added an if bb
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# We can now see the hazards produced by engine-<I> with engine <I> [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Some work on SourceModelLogicTree.__fromh5__ [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Forbidden grid and sites at the same time [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Implements DeferrableProvider
#
# $defer = true will be removed in <I>, might as well port to DeferrableProvider right now.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   illuminate_auth
# ___
# 10)
# [<I>] Generate a URL to an application asset from a root domain such as CDN etc.
#
# This would simplify generating asset when you need to specify different root domain/url as the request. Alternative to laravel/framework#<I> PR.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# _________________
#
# Number of messages in this class: 2374
# Most common committers:
# [('mark@mark-story.com', 275), ('mike@silverorange.com', 269)]
# Most common project:
# ('saltstack_salt', 272)
#
#
#
# ________________ Class 15 ________________
#
# ___
# 1)
# Fixed openquake/engine/tests/calculators/hazard/post_processing_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed hazardlib/tests/calc/stochastic_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Add Orchestra/Html/Form/Field and Orchestra/Html/Table/Column
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 4)
# lxd/cluster/gateway: Add HeartbeatOfflineThreshold var
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# lxd/instance/drivers/driver/qemu: Add input checks to addDriveConfig
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# lxd/storage/pools/utils: Comment on storagePoolDBCreate
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/storage/drivers/driver/btrfs/volumes: Adds safety net against failed matching of subvolumes
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/main/init/interactive: Error wrapping
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/device/nic/physical: SetMTU usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/storage/backend/mock: Adds Description, Status and LocalStatus functions
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 1046
# Most common committers:
# [('thomas.parrott@canonical.com', 842), ('stgraber@ubuntu.com', 66)]
# Most common project:
# ('lxc_lxd', 908)
#
#
#
# ________________ Class 16 ________________
#
# ___
# 1)
# Added a correction factor of <I> to point sources
#
#
# Former-commit-id: b9d6a<I>d<I>c<I>dc<I>ed6f3fc2ff<I>fe
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added a comment
#
#
# Former-commit-id: 1dcd<I>dad<I>d3df<I>e<I>fc<I>ff5fd<I>a6fef0
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small cleanup of oq check_input [skip CI]
#
#
# Former-commit-id: <I>ce<I>b<I>d<I>a<I>bc<I>c<I>ef<I>e9ea
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Reflected the change in the weighting algorithm
#
#
# Former-commit-id: 1b<I>e<I>fd<I>ec<I>a<I>ca<I>cf9d<I>e<I>f [formerly e<I>ec<I>afdb0dc6e3a<I>fdf<I>c<I>ca0ad<I>]
# Former-commit-id: eb<I>bd<I>c5f<I>c<I>cfea<I>e<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Removed a remaining reference to models.SiteCollection in the scenario calculator
#
#
# Former-commit-id: d<I>a<I>d<I>c1ec<I>f<I>c6b [formerly 1df<I>b0ff0d0e<I>a7f<I>faa<I>bb<I>f]
# Former-commit-id: 8fc<I>cbf9f8e<I>bd9a<I>ee<I>fcd<I>c<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added an useful Socket.__repr__
#
#
# Former-commit-id: ede<I>e<I>a<I>f<I>db1c<I>ba<I>a6aab<I>c0a2 [formerly 2d<I>c1de<I>a0e2b<I>cc<I>a<I>a<I>c<I>c]
# Former-commit-id: e9ab<I>e9aa3e<I>f5f<I>c<I>a<I>aa<I>bd3
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Restored dask support
#
#
# Former-commit-id: <I>a6b6e<I>e6bbe7ab<I>b8dfc<I>dd<I>ba2 [formerly f8dc<I>e<I>f3c<I>f<I>a0f3f8f2c<I>]
# Former-commit-id: b8d9d8b<I>f5ad<I>eb<I>c<I>fefba<I>c4dd5d
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Removed obsolete function
#
#
# Former-commit-id: c<I>c<I>a3d<I>f5a<I>c<I>b2de1dc1aed<I>a4a
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Make sure there is rupture-filtering in the scenario calculator
#
#
# Former-commit-id: <I>b<I>c<I>c<I>e7c0d<I>c<I>bb<I>d3a8
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Fix in the workerpool [skip CI]
#
#
# Former-commit-id: ff5f4c<I>cfdc<I>d<I>b<I>b<I>a<I>a<I>c<I> [formerly <I>b<I>bf<I>fcdd6f4d<I>afbea<I>e<I>]
# Former-commit-id: d<I>d<I>cfbc<I>db<I>aa<I>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1866
# Most common committers:
# [('michele.simionato@gmail.com', 1484), ('Lars.Butler@gmail.com', 216)]
# Most common project:
# ('gem_oq-engine', 1700)
#
#
#
# ________________ Class 17 ________________
#
# ___
# 1)
# Solved discard_trts not working with UCERF
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Run case_master only in the REFERENCE_OS
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Saving damages-rlzs in event_based_damage too
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Changed the default export to csv instead of xml
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed UCERF with OQ_SAMPLE_SOURCES again
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Fixed bug with individual_curves not interpreted as individual_rlzs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Used rtree=None instead of False
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Rollback only if a transaction is on
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# keep in memory the loss_matrix only when doing disaggregation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Insert the IMT in the db, if not already there
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 798
# Most common committers:
# [('aaron.patterson@gmail.com', 58), ('jaraco@jaraco.com', 48)]
# Most common project:
# ('rails_rails', 61)
#
#
#
# ________________ Class 18 ________________
#
# ___
# 1)
# Improved collect_info to consider extendModel
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Added an exports argument to export
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Updated .received to be a list
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Added some defaults to run.run
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Tried to produce more tasks for classical_tiling
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Changed oq workers kill to use killall
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Added expose_outputs to compare_with_classical
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Used masked arrays to manage missing costs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Added a test to make sure that Curves are pickeable
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Changed test_invalid_export_dir to make Jenkins happy
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 835
# Most common committers:
# [('jaraco@jaraco.com', 59), ('thatch45@gmail.com', 56)]
# Most common project:
# ('saltstack_salt', 125)
#
#
#
# ________________ Class 19 ________________
#
# ___
# 1)
# Made workflows.Scenario consistent with the engine calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Use provider for consistent language.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 3)
# Remove alias from service provider.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 4)
# Improves performance by swapping offsetGet with make.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_facile
# ___
# 5)
# Add load migration from.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 6)
# Avoid setting up test environment twice.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-dusk
# ___
# 7)
# Readd for backward compatibility.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 8)
# Remove alias from service provider.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 9)
# Fixes usage of use.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 10)
# Check for mockery type array.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_codex
# _________________
#
# Number of messages in this class: 1166
# Most common committers:
# [('mark@mark-story.com', 219), ('taylorotwell@gmail.com', 182)]
# Most common project:
# ('cakephp_cakephp', 202)
#
#
#
# ________________ Class 20 ________________
#
# ___
# 1)
# Removed parallel.Sequential
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Rename method.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 3)
# Tweak prepareRequestPayloads.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 4)
# fixed coverage.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 5)
# Import class.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# ___
# 6)
# Small tweak.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 7)
# Cleanup requirement.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_installer
# ___
# 8)
# Tweak code.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 9)
# Small fixes.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 10)
# Fixed variable name.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# _________________
#
# Number of messages in this class: 215
# Most common committers:
# [('crynobone@gmail.com', 186), ('postmodern.mod3@gmail.com', 13)]
# Most common project:
# ('orchestral_foundation', 42)
#
#
#
# ________________ Class 21 ________________
#
# ___
# 1)
# Restored task_splitting even with the dcache [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Reduced error to warning [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Measuring memory in computing_risk [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Showing also the median in oq plot [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Run RuptureGetter.get_eid_rlz sequentially if there are few sites [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Disabled task splitting in presence of a dcache [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Small fix in oq show branch_ids [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Error->print for unknown GMPE methods [ci s kip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fixed oq info smlt.xml to manage extendModel [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Displayed also the total task time in view_task_ebrisk [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1109
# Most common committers:
# [('mjpt777@gmail.com', 769), ('marijnh@gmail.com', 89)]
# Most common project:
# ('real-logic_aeron', 675)
#
#
#
# ________________ Class 22 ________________
#
# ___
# 1)
# Added classical and disaggregation to the PRECALC_MAP
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed a cut and paste bug in ComplexFaultSurface
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Making losses_by_event the same between ebrisk and scenario_risk
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Avoid excessive calling _get_rupture_dimensions and get_median_area
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Added collapse_factor and pointsource_distance in the hazard checksum
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added start_time and stop_time to the response_data for engine server calculations
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Forced pointsource_distance and removed collapse_distance
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Generalized spinning_distance and floating_distance
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Generated hcurves and stats
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Made sure the monitor has attribute task_no and weight
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 912
# Most common committers:
# [('jaraco@jaraco.com', 108), ('ben.gyori@gmail.com', 54)]
# Most common project:
# ('saltstack_salt', 84)
#
#
#
# ________________ Class 23 ________________
#
# ___
# 1)
# Add monitor support to litetasks
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Changed calcgmfs to accept multiple seeds
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small fix to the RecordBuilder to manage string fields
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Changed OqParam.cross_correl to return None for NoCorrelation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Passed exports to Calculator.export
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Small fix to make_html_report
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Microfix to CallableDict keymissing
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Trying to fix latex encoding
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Added DO NOT USE warning to the conditional_spectrum calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Changed event_based_risk to honor concurrent_tasks
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 908
# Most common committers:
# [('thatch45@gmail.com', 169), ('ben.gyori@gmail.com', 97)]
# Most common project:
# ('saltstack_salt', 281)
#
#
#
# ________________ Class 24 ________________
#
# ___
# 1)
# Fixed build_header doctest
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Make sure the exported zip files are compressed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Made sure DictArray is not empty
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Added a sanity check to make sure that the stored num_tasks is correct
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Improved the traceback returned by safely_call
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Make sure write_csv uses UTF-8
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Added a tests checking that setval is called correctly
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Made sure the latest commit of a branch is downloaded
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Only one realization is accepted in GMFs in CSV format [skip hazardlib]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Restored a += accidentally removed
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 752
# Most common committers:
# [('ns@vivid-planet.com', 88), ('P.Rudiger@ed.ac.uk', 35)]
# Most common project:
# ('saltstack_salt', 89)
#
#
#
# ________________ Class 25 ________________
#
# ___
# 1)
# <3 PSR-2
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 2)
# Call self[:host] directly.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin
# ___
# 3)
# Forgot a Database.setup.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin
# ___
# 4)
# [Core] Fix the phpDoc comments.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 5)
# [Core] Adjust a phpDoc comment.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 6)
# [Comments] Various minor issues
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 7)
# [Manager] Add a missing phpDoc comment.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 8)
# [Calendar] Fix a yoda condition.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 9)
# [Faq] Update the copyright date.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 10)
# [Installation] Implement the ContainerAwareInterface interface.
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# _________________
#
# Number of messages in this class: 628
# Most common committers:
# [('mjpt777@gmail.com', 480), ('github@contao.org', 99)]
# Most common project:
# ('real-logic_aeron', 400)
#
#
#
# ________________ Class 26 ________________
#
# ___
# 1)
# Ported more GMPE tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed the disagg QA tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Extended compute_stats to composite arrays
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Ported some GMPE test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Introduced function valid.namelists
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Enforced the num_cores limitation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Restored gsim.set_parameters also for planar ruptures
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Ported more GMPE tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Added openquake.calculators tests
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Restored tests on the loss maps
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 712
# Most common committers:
# [('P.Rudiger@ed.ac.uk', 94), ('igor.kroitor@gmail.com', 65)]
# Most common project:
# ('saltstack_salt', 90)
#
#
#
# ________________ Class 27 ________________
#
# ___
# 1)
# Moved a log.info -> log.debug
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed bug introduced in <URL>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Small change to the docs suggested by <URL>
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   micheles_decorator
# ___
# 4)
# An alternate implementation inspired by <URL>
#
# - - -
# Committer: jaraco@jaraco.com
# Project:   jaraco_jaraco.functools
# ___
# 5)
# Added specs for String#base<I>_encode and String#base<I>_decode.
#
# - - -
# Committer: postmodern.mod3@gmail.com
# Project:   ronin-ruby_ronin
# ___
# 6)
# Exchange.php sort_by_2
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 7)
# async-basic.py PEP8
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 8)
# _1broker fetchTicker consistency
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 9)
# kraken changed the markup of <URL>
#
# - - -
# Committer: igor.kroitor@gmail.com
# Project:   ccxt_ccxt
# ___
# 10)
# socket.connect needs a tuple
# TypeError
# <URL>
#
# - - -
# Committer: pedro@algarvio.me
# Project:   saltstack_salt
# _________________
#
# Number of messages in this class: 1012
# Most common committers:
# [('blickly@google.com', 951), ('moodler', 12)]
# Most common project:
# ('google_closure-compiler', 951)
#
#
#
# ________________ Class 28 ________________
#
# ___
# 1)
# lxd/networks: Updates doNetworkUpdate to support projects
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 2)
# lxd/networks: d.cluster.GetNetworkInAnyState usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 3)
# lxd/storage/utils: drivers.NewVolume usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# lxd/daemon: db.OpenCluster usage in init
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# lxd/images: Comment weaks
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# lxd/util/net: Improve comment in CanonicalNetworkAddress
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/images: Updates autoUpdateImage to use d.ImageDownload
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# lxd/events: d.events.AddListener usage
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/device/disk: Consistent comment line endings
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/images: golint fixes
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 711
# Most common committers:
# [('thomas.parrott@canonical.com', 402), ('stgraber@ubuntu.com', 208)]
# Most common project:
# ('lxc_lxd', 610)
#
#
#
# ________________ Class 29 ________________
#
# ___
# 1)
# Added __wrapped__ even to the high level usage of decorator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   micheles_decorator
# ___
# 2)
# Refactored Socket.__iter__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Not removing __pyclass__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Improved File.__fromh5__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed a serious bug in ProbabilityMap.__or__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Solved a very tricky bit with __nonzero__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Used humansize in the __repr__ of the Monitor class
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Small enhancement to IntegrationDistance.__call__
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Fixed _submit_many
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Optimized ProbabilityMap.__iadd__ further
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 388
# Most common committers:
# [('pedro@algarvio.me', 108), ('jaraco@jaraco.com', 31)]
# Most common project:
# ('saltstack_salt', 147)
#
#
#
# ________________ Class 30 ________________
#
# ___
# 1)
# Added a minimum task_duration of <I> seconds [skip CI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Storing _csm if OQ_SAMPLE_SOURCES is set [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Changed the backend to inproc:// [demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed a useless exclude=[]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed type bug in compute_pmap_stats [skipCI]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Laravel <I> should have boostrapPath() by default.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_api
# ___
# 7)
# Fixes return type should consist of [$headers, $body]
#
# - - -
# Committer: crynobone@gmail.com
# Project:   jomweb_billplz
# ___
# 8)
# [#1] Add Orchestra\Model\Role events to update ACL.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# [Core] Improve the NULL check in the Widget class (see #<I>).
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# ___
# 10)
# [Core] Correctly update the `tl_files` table during the version <I> update (see #<I>)
#
# - - -
# Committer: github@contao.org
# Project:   contao_contao
# _________________
#
# Number of messages in this class: 1305
# Most common committers:
# [('github@contao.org', 1045), ('taylor@laravel.com', 78)]
# Most common project:
# ('contao_contao', 1045)
#
#
#
# ________________ Class 31 ________________
#
# ___
# 1)
# Remove an un-needed django.setup()
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed merge-induced misprint [ci skip]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Compute avg_losses-stats only when requested
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Raised h5py version
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Fixed a very subtle initialization bug breaking risk/event_based/core_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Removed an un-needed if
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# FIxes `php artisan key:generate` failed due to used of hardcoded app path config.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_framework
# ___
# 8)
# lxd/device/nic/bridged: Allow using IP filtering with an unmanaged parent bridge
#
# Only if there is a manually specified IP to use for filtering.
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# ...
# ___
# 10)
# Use lapse instead of seconds.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_profiler
# _________________
#
# Number of messages in this class: 487
# Most common committers:
# [('postmodern.mod3@gmail.com', 209), ('crynobone@gmail.com', 59)]
# Most common project:
# ('ronin-ruby_ronin', 122)
#
#
#
# ________________ Class 89 ________________
#
# ___
# 1)
# Added a test for extract/composite_risk_model.attrs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed misprint in extract/losses_by_asset
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Remove requirement to explicitly finish/terminate orchestra/memory
# during console command.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 4)
# Add confirmation to `php artisan extension:refresh` command.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 5)
# Remove publisher/ftp
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Tweak console response for 'artisan orchestra:extension detect'
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 7)
# Update code based on orchestral/support@1d5febb
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_memory
# ___
# 8)
# lxd/util/http: Fix CheckTrustState to block access for revoked certificates that were formerly trusted
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# shared/instance: Adds volatile.apply_nvram config key
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# container/lxc: Adds error checking for calls to networkClearLease
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 803
# Most common committers:
# [('mitchell.hashimoto@gmail.com', 304), ('thomas.parrott@canonical.com', 125)]
# Most common project:
# ('lxc_lxd', 230)
#
#
#
# ________________ Class 90 ________________
#
# ___
# 1)
# Fixed report_writer.count_eff_ruptures
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed performance_monitor_test
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed DISPLAY_NAME
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Unskipped source_test.py
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Restored calcgmfs
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Added method SourceFilter.get_nsites
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Optimized apply_correlation
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Fixed FragilityFunctionContinuous
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Managed in_cshm
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Fixed view mean_avg_losses
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 181
# Most common committers:
# [('michele.simionato@gmail.com', 115), ('tj@vision-media.ca', 26)]
# Most common project:
# ('gem_oq-engine', 115)
#
#
#
# ________________ Class 91 ________________
#
# ___
# 1)
# Removed the .csv export feature, since it is still experimental
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restored the RecordBuilder as it was
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Remove the loss_curve_resolution default, since it is done in commonlib.readinput
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Simplified BaseSeismicSource.sample_ruptures now that we can
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Not computing avg_gmf if gmf_df is too big
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Restored gsims as it was
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Restore save_disk_space as it was
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Run the hazard stats in parallel only if there are many sites [skip hazardlib][demos]
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Restored save_vlen as it was
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# Now openquake.cfg can be found even if you are not in the openquake directory
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 1356
# Most common committers:
# [('zacharyspector@gmail.com', 141), ('aaron.patterson@gmail.com', 128)]
# Most common project:
# ('saltstack_salt', 155)
#
#
#
# ________________ Class 92 ________________
#
# ___
# 1)
# Removed offending reading of the ~ hdf5 file
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Worked around ValueError: Unrecognized type code -1
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixes using input:password instead of password.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# ___
# 4)
# container/lxc: Fix description
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 5)
# lxd: Enable gorilla UseEncodedPath
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 6)
# device/runconfig: Fix typo in comment
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 7)
# lxd/migrate: Fix crash in sendControl when no active connection
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 8)
# client/connection: Correct HTTPs to HTTPS in ConnectPublicLXD
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 9)
# lxd/networks: Validate network name earlier in networksPost
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 10)
# lxd/networks: Validate network config before starting networks on startup
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# _________________
#
# Number of messages in this class: 683
# Most common committers:
# [('ccordoba12@gmail.com', 165), ('hajimehoshi@gmail.com', 94)]
# Most common project:
# ('spyder-ide_spyder', 146)
#
#
#
# ________________ Class 93 ________________
#
# ___
# 1)
# Commented out self.zmaster.start() breaking the cluster
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Fixed a confusion in actual_path/actual_dir
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Fixed the name of a field (risk_job_id->job_id)
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Append extension information to runtime right after activate(), this is to allow extension information to be fetch using option() method.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 5)
# Use getcwd() to determine working path.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 6)
# dl() now supports multiple descriptions per term
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_html
# ___
# 7)
# Remove reference to getLayout() from ControllerDispatcher.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravel_framework
# ___
# 8)
# Add withInput() on fail database transaction
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# Change Orchestra\Extension\Dispatcher::start() visibility to public.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# ___
# 10)
# Fixed 'Strict standards: Declaration of Orchestra\Support\Manager::callCustomCreator() should be compatible with that of Illuminate\Support\Manager::callCustomCreator()'
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# _________________
#
# Number of messages in this class: 1172
# Most common committers:
# [('ingo@silverstripe.com', 128), ('jerome@leclan.ch', 103)]
# Most common project:
# ('moodle_moodle', 92)
#
#
#
# ________________ Class 94 ________________
#
# ___
# 1)
# Saving memory in get_mean_stds
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Back to bytes string in source_info_dt
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Raised tolerance in scenario_risk/case_4
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Using iter_native in celery
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Using start_new_session in Popen
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Turned error into logging.error
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Changed the queue to work in FIFO
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Fix in server.views.extract
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 9)
# Restore save_ruptures to False
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 10)
# I restore validation after writing in node_to_nrml
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# _________________
#
# Number of messages in this class: 852
# Most common committers:
# [('jaraco@jaraco.com', 84), ('thatch45@gmail.com', 79)]
# Most common project:
# ('saltstack_salt', 142)
#
#
#
# ________________ Class 95 ________________
#
# ___
# 1)
# Fixes migration changes.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 2)
# Fixes syntax.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_support
# ___
# 3)
# Fixes testcase.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 4)
# Fixes invalid key.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 5)
# Fixes test.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Fixes test case.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 7)
# Boot lumen first.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_lumen
# ___
# 8)
# Fixes typo.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 9)
# Fixes routing issues.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_story
# ___
# 10)
# Fixes variable name.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# _________________
#
# Number of messages in this class: 188
# Most common committers:
# [('crynobone@gmail.com', 186), ('jaraco@jaraco.com', 1)]
# Most common project:
# ('orchestral_foundation', 44)
#
#
#
# ________________ Class 96 ________________
#
# ___
# 1)
# Use ::class constant.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_imagine
# ___
# 2)
# use ::class constant.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_kernel
# ___
# 3)
# Use ::class constant.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   laravie_html
# ___
# 4)
# depgraph: fmt
#
# - - -
# Committer: mitchell.hashimoto@gmail.com
# Project:   hashicorp_terraform
# ___
# 5)
# command/push: archiving
#
# - - -
# Committer: mitchell.hashimoto@gmail.com
# Project:   hashicorp_terraform
# ___
# 6)
# common @jonleighton :bomb:
#
# - - -
# Committer: aaron.patterson@gmail.com
# Project:   rails_rails
# ___
# 7)
# :anchor: Fix a typo
#
# - - -
# Committer: blactbt@live.de
# Project:   meew0_discordrb
# ___
# 8)
# :anchor: Implement Client#execute
#
# - - -
# Committer: blactbt@live.de
# Project:   meew0_discordrb
# ___
# 9)
# :anchor: Implement Client#post_json
#
# - - -
# Committer: blactbt@live.de
# Project:   meew0_discordrb
# ___
# 10)
# bencode: gofmt
#
# - - -
# Committer: anacrolix@gmail.com
# Project:   anacrolix_torrent
# _________________
#
# Number of messages in this class: 135
# Most common committers:
# [('avwu@qq.com', 100), ('ronnie@dio.jp', 20)]
# Most common project:
# ('avwo_whistle', 97)
#
#
#
# ________________ Class 97 ________________
#
# ___
# 1)
# Preserving the argument order in sap.Script
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Changed self.N to be the number of filtered sites
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Removed the last reference to .calc_id
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Removed a reference to /tmp
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 5)
# Removed a remaining reference to models.SiteCollection in the scenario calculator
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 6)
# Small fix to the TaskManager.progress
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 7)
# Raised an error for soil_intensities with amplification_method != convolution
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 8)
# Rename a variable.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_control
# ___
# 9)
# Just a simple reorganization.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_notifier
# ___
# 10)
# Add some odd test due to funkiness of static macro.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_html
# _________________
#
# Number of messages in this class: 1101
# Most common committers:
# [('postmodern.mod3@gmail.com', 474), ('jaraco@jaraco.com', 101)]
# Most common project:
# ('ronin-ruby_ronin', 270)
#
#
#
# ________________ Class 98 ________________
#
# ___
# 1)
# device: Links gpu device
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 2)
# client: Removes nullReadWriteCloser
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 3)
# container: Adds DeviceEventHandler to interface
#
# - - -
# Committer: thomas.parrott@canonical.com
# Project:   lxc_lxd
# ___
# 4)
# Setup.py: Remove wrong classifier
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_qtpy
# ___
# 5)
# Docs: Update Spyder version
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder
# ___
# 6)
# UMR: Fix Cython support
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder-kernels
# ___
# 7)
# Variable Explorer: Simplify operation
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder
# ___
# 8)
# Editor: Simplify Python shebang detection
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder
# ___
# 9)
# LSP: Remove repeated SymbolKind enum
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder
# ___
# 10)
# Icons: Decrease debugger arrow size
#
# - - -
# Committer: ccordoba12@gmail.com
# Project:   spyder-ide_spyder
# _________________
#
# Number of messages in this class: 303
# Most common committers:
# [('avwu@qq.com', 213), ('hajimehoshi@gmail.com', 18)]
# Most common project:
# ('avwo_whistle', 206)
#
#
#
# ________________ Class 99 ________________
#
# ___
# 1)
# Added attribute .epsilons=None
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 2)
# Restored risk_imtls
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 3)
# Support soil_levels=None
#
# - - -
# Committer: michele.simionato@gmail.com
# Project:   gem_oq-engine
# ___
# 4)
# Improve testcase
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_tenanti
# ___
# 5)
# Remove unused code
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_foundation
# ___
# 6)
# Add use Illuminate\Foundation\Publishing\AssetPublisher
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_publisher
# ___
# 7)
# Defer the CommandServiceProvider
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_auth
# ___
# 8)
# Update facile classes rename
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_optimize
# ___
# 9)
# Update collision
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_testbench-core
# ___
# 10)
# Add missing IoC.
#
# - - -
# Committer: crynobone@gmail.com
# Project:   orchestral_extension
# _________________
#
# Number of messages in this class: 161
# Most common committers:
# [('crynobone@gmail.com', 39), ('igor.kroitor@gmail.com', 18)]
# Most common project:
# ('ccxt_ccxt', 18)

# %% [markdown]
# A kmeans model was trained on the vectors spacy calculates for each document.
#
# This clustering approach can detect some commonalities in between the commit messages. For example, in one cluster all messages include the tag &lt;I>, in others there is always something that is fixed, some always have an URL or a file path and also lengths and sentence structure can be equal in classes sometimes.
#
# That is why one could argue that messages in one resulting cluster of k-means should have approximately equal quality.

# %% [markdown]
# Idea: Use the "Elbow method" to calculate the best fitting number of cluster centers.
#
# https://github.com/Hassaan-Elahi/Writing-Styles-Classification-Using-Stylometric-Analysis
